# %% [markdown]
# # Q1. Explain GET and POST methods.

# %% [markdown]
# **GET** requests are used to retrieve data from a server. When a user clicks a link or types a URL into their browser's address bar, the browser sends a GET request to the server to retrieve the HTML content of the requested page. The data is sent in the URL as a query string, which is visible in the browser's address bar. GET requests are also used in AJAX requests, where they can be used to retrieve data from a server without refreshing the entire page.
#
# **POST** requests, on the other hand, are used to submit data to a server. When a user submits a form, the form data is sent in the body of a POST request to the server for processing. This method is commonly used in web applications to submit data to the server, such as when a user creates a new account, submits a comment, or makes a purchase. Unlike GET requests, POST requests do not display the data in the URL, making them more secure for transmitting sensitive information.

# %% [markdown]
# # Q2. Why is request used in Flask?

# %% [markdown]
# In Flask, the request object is used to access data that a client sends to a server as part of an HTTP request. It provides a way for the server-side code to access the data submitted by the client, such as form data, query parameters, and file uploads.
#
# The request object is an instance of the Request class and is automatically created by Flask when a request is received. The object contains a variety of useful attributes and methods that allow you to access different parts of the request data.
#
# By using the request object in your Flask application, you can easily access the data submitted by the client and use it to generate a response. For example, you can use the data submitted in a form to process a user's request, or you can use the query parameters in a URL to return different results based on the user's input.

# %% [markdown]
# # Q3. Why is redirect() used in Flask?

# %% [markdown]
# In Flask, the **redirect()** function is used to redirect the client's web browser to a different URL. The redirect() function is typically used in web applications to send the user to a different page after they have completed a certain action, such as submitting a form or logging in.

# %% [markdown]
# # Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# In Flask, **templates** are used to separate the presentation layer of a web application from its business logic. A template is a file that contains a mix of HTML, CSS, and placeholders for dynamic data, which can be populated with data from the application at runtime.
#
# The **render_template()** function is used to render a template and generate an HTML response that can be sent to the client's web browser. The **ender_template()** function takes the name of the template as its first argument and any additional keyword arguments representing the dynamic data that should be included in the template.

# %% [markdown]
# # Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![postman.png](attachment:435a6e39-17a3-4b62-b531-18ae705ed788.png)
